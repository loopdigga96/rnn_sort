# %%
import numpy as np

# Neural networks take input as vectors so we have to convert integers to vectors using one-hot encoding
# This function will encode a given integer sequence into RNN compatible format (one-hot representation)

def encode(X,seq_len, vocab_size):
    x = np.zeros((len(X),seq_len, vocab_size), dtype=np.float32)
    for ind,batch in enumerate(X):
        for j, elem in enumerate(batch):
            x[ind, j, elem] = 1
    return x


# This is a generator function which can generate infinite-stream of inputs for training

def batch_gen(batch_size=32, seq_len=10, max_no=999):
    # Randomly generate a batch of integer sequences (X) and its sorted
    # counterpart (Y)
    x = np.zeros((batch_size, seq_len, max_no), dtype=np.float32)
    y = np.zeros((batch_size, seq_len, max_no), dtype=np.float32)

    while True:
        # Generates a batch of input
        X = np.random.randint(max_no, size=(batch_size, seq_len))

        Y = np.sort(X, axis=1)

        for idx, batch in enumerate(X):
            for j, elem in enumerate(batch):
                x[idx, j, elem] = 1

        for idx, batch in enumerate(Y):
            for j, elem in enumerate(batch):
                y[idx, j, elem] = 1

        yield x, y
        x.fill(0.0)
        y.fill(0.0)

# %%
from keras.models import Sequential
from keras.layers.core import Activation, RepeatVector, Dropout, Dense
from keras.layers import recurrent, TimeDistributed
import numpy as np
#from data import batch_gen, encode
RNN = recurrent.LSTM

# global parameters.
batch_size=32
seq_len = 10
max_no = 20

# Initializing model 
model = Sequential()

# This is encoder RNN (we are taking a variant of RNN called LSTM, because plain RNN's suffer from long-term dependencies issues
model.add(RNN(100, input_shape=(seq_len, max_no)))

# Dropout to enhace RNN's generalization capacities 
model.add(Dropout(0.25))

# At this point RNN will generate a summary vector of the sequence, so to feed it to decoder we need to repeat it lenght of output seq. number of times
model.add(RepeatVector(seq_len))

# Decoder RNN, which will return output sequence 
model.add(RNN(100, return_sequences=True))

# Adding linear layer at each time step 
model.add(TimeDistributed(Dense(max_no)))

# Adding non-linearity on top of linear layer at each time-step, since output at each time step is supposed to be probability distribution over max. no of integer in sequence
# we add softmax non-linearity
model.add(Dropout(0.5))
model.add(Activation('softmax'))

# Since this is a multiclass classification task, crossentropy loss is being used. Optimizer is adam, which is a particular instance of adaptive learning rate Gradient Descent methods
model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# Now the training loop, we'll sample input batches from the generator function written previously and feed it to the RNN for learning

for ind,(X,Y) in enumerate(batch_gen(batch_size, seq_len, max_no)):
    loss, acc = model.train_on_batch(X, Y)
    # We'll test RNN after each 250 iteration to check how well it is performing
    if ind % 250 == 0:
        testX = np.random.randint(max_no, size=(1, seq_len))
        test = encode(testX, seq_len, max_no)
        print(testX)
        #pdb.set_trace()
        y = model.predict(test, batch_size=1)
        print ("actual sorted output is")
        print (np.sort(testX))
        print ("sorting done by RNN is")
        print (np.argmax(y, axis=2))
        print ("\n")
# Out:
# [[ 4 19 13 12  5  4  7  9 15  4]]
# actual sorted output is
# [[ 4  4  4  5  7  9 12 13 15 19]]
# sorting done by RNN is
# [[17 17 17 17 17 17 17 17 17 17]]
#
#
# [[ 7 19 12  5 13  0  4  6  4  0]]
# actual sorted output is
# [[ 0  0  4  4  5  6  7 12 13 19]]
# sorting done by RNN is
# [[ 0  1  4  4  6  7  7 12 12 19]]
#
#
# [[ 3  6  8  9 10 12  6  5  9 17]]
# actual sorted output is
# [[ 3  5  6  6  8  9  9 10 12 17]]
# sorting done by RNN is
# [[ 0  6  6  6  9  9  9 10 12 12]]
#
#
# [[18  1 10  3 11  1 12  0  7 13]]
# actual sorted output is
# [[ 0  1  1  3  7 10 11 12 13 18]]
# sorting done by RNN is
# [[ 0  1  1  3  7 10 11 12 13 18]]
#
#
# [[17 18  2  6 12  9  6 11  1 19]]
# actual sorted output is
# [[ 1  2  6  6  9 11 12 17 18 19]]
# sorting done by RNN is
# [[ 0  2  6  6  9 11 12 17 18 19]]
#
#
# [[13 14 17  3  1 17 16 17  8 12]]
# actual sorted output is
# [[ 1  3  8 12 13 14 16 17 17 17]]
# sorting done by RNN is
# [[ 1  3  8 12 13 14 16 17 17 17]]
#
#
# [[ 7  5 15  0 10  8  2 16  9 19]]
# actual sorted output is
# [[ 0  2  5  7  8  9 10 15 16 19]]
# sorting done by RNN is
# [[ 0  2  5  7  8  9 10 15 16 19]]
#
#
# [[15 11 16 12 14  3 14 14  5  9]]
# actual sorted output is
# [[ 3  5  9 11 12 14 14 14 15 16]]
# sorting done by RNN is
# [[ 3  5  9 11 12 14 14 14 15 16]]
#
#
# [[ 3  0 11  5 14  4  7  1 17  8]]
# actual sorted output is
# [[ 0  1  3  4  5  7  8 11 14 17]]
# sorting done by RNN is
# [[ 0  1  3  4  5  7  8 11 14 17]]
#
#
# [[10  2  8  5  0  8  3  5  9  9]]
# actual sorted output is
# [[ 0  2  3  5  5  8  8  9  9 10]]
# sorting done by RNN is
# [[ 0  2  3  5  5  8  8  9 10 10]]
#
#
# [[ 3  6  9  2 18  7  0  7 12  8]]
# actual sorted output is
# [[ 0  2  3  6  7  7  8  9 12 18]]
# sorting done by RNN is
# [[ 0  2  3  6  7  7  8  9 12 18]]
#
#
# [[ 4 15  8 19  5  2  1  6 10 14]]
# actual sorted output is
# [[ 1  2  4  5  6  8 10 14 15 19]]
# sorting done by RNN is
# [[ 1  2  4  5  6  8 10 14 15 19]]
#
#
# [[ 5  3  7 14 14  0 15  0 18 18]]
# actual sorted output is
# [[ 0  0  3  5  7 14 14 15 18 18]]
# sorting done by RNN is
# [[ 0  0  3  5  7 14 14 15 18 18]]
#
#
# [[18 10 11  9 12 14  6 10 17 10]]
# actual sorted output is
# [[ 6  9 10 10 10 11 12 14 17 18]]
# sorting done by RNN is
# [[ 6  9 10 10 10 11 12 14 17 18]]
#
#
# [[ 9  9  6 14  8  7 18 10  2 11]]
# actual sorted output is
# [[ 2  6  7  8  9  9 10 11 14 18]]
# sorting done by RNN is
# [[ 2  6  7  8  9  9 10 11 14 18]]
#
#
# [[ 8 14 11 16 19 16 15 13  2 14]]
# actual sorted output is
# [[ 2  8 11 13 14 14 15 16 16 19]]
# sorting done by RNN is
# [[ 2  8 11 13 14 14 15 16 16 19]]
#
#
# [[14  6  7 17  7 14  1  1 17  9]]
# actual sorted output is
# [[ 1  1  6  7  7  9 14 14 17 17]]
# sorting done by RNN is
# [[ 1  1  6  7  7  9 14 14 17 17]]
#
#
# [[ 0  9 10 13  9  5  8 11  2 17]]
# actual sorted output is
# [[ 0  2  5  8  9  9 10 11 13 17]]
# sorting done by RNN is
# [[ 0  2  5  8  9  9 10 11 13 17]]
#
#
# [[16 16  3  4  6 16  9 10  9  5]]
# actual sorted output is
# [[ 3  4  5  6  9  9 10 16 16 16]]
# sorting done by RNN is
# [[ 3  4  5  6  9 10 10 16 16 16]]
#
#
# [[11 11  1  9  9  2 17 19  8 16]]
# actual sorted output is
# [[ 1  2  8  9  9 11 11 16 17 19]]
# sorting done by RNN is
# [[ 1  2  8  9  9 11 11 16 17 19]]
#
#
# [[16 18  4 17 13 13 13 12  0  7]]
# actual sorted output is
# [[ 0  4  7 12 13 13 13 16 17 18]]
# sorting done by RNN is
# [[ 0  4  7 12 13 13 13 16 17 18]]
#
#
# [[ 3 19 16  5  9 19  5  0  8 19]]
# actual sorted output is
# [[ 0  3  5  5  8  9 16 19 19 19]]
# sorting done by RNN is
# [[ 0  3  5  5  8  9 16 19 19 19]]
#
#
# [[ 9 15  4  0 11  3  5 16  3 12]]
# actual sorted output is
# [[ 0  3  3  4  5  9 11 12 15 16]]
# sorting done by RNN is
# [[ 0  3  3  4  5  9 11 12 15 16]]
#
#
# [[ 4 12 12  5  8  2 16  8 15  3]]
# actual sorted output is
# [[ 2  3  4  5  8  8 12 12 15 16]]
# sorting done by RNN is
# [[ 2  3  4  5  8  8 12 12 15 16]]
#
#
# [[14  8  8  9  4 14  3 15 16  8]]
# actual sorted output is
# [[ 3  4  8  8  8  9 14 14 15 16]]
# sorting done by RNN is
# [[ 3  4  8  8  8  9 14 14 15 16]]
#
#
# [[16  7  1  0 18 16  9 19  4 17]]
# actual sorted output is
# [[ 0  1  4  7  9 16 16 17 18 19]]
# sorting done by RNN is
# [[ 0  1  4  7  9 16 16 17 18 19]]
#
#
# [[19  8 11  2 10  5  3 19  0  3]]
# actual sorted output is
# [[ 0  2  3  3  5  8 10 11 19 19]]
# sorting done by RNN is
# [[ 0  2  3  3  5  8 10 11 19 19]]
#
#
# [[19 10  4  6  6  2 16  6  0  5]]
# actual sorted output is
# [[ 0  2  4  5  6  6  6 10 16 19]]
# sorting done by RNN is
# [[ 0  2  4  5  6  6  6 10 16 19]]
#
#
# [[ 3 17  8 17  4 13 11 14  5  3]]
# actual sorted output is
# [[ 3  3  4  5  8 11 13 14 17 17]]
# sorting done by RNN is
# [[ 3  3  4  5  8 11 13 14 17 17]]
#
#
# [[ 6 11 11  3 12 14  9 13 16  5]]
# actual sorted output is
# [[ 3  5  6  9 11 11 12 13 14 16]]
# sorting done by RNN is
# [[ 3  5  6  9 11 11 12 13 14 16]]
#
#
# [[ 2 16 15 18  5 19  1  3 12  2]]
# actual sorted output is
# [[ 1  2  2  3  5 12 15 16 18 19]]
# sorting done by RNN is
# [[ 1  2  2  3  5 12 15 16 18 19]]
#
#
# [[10  1 17 14 18 12  1  1 12 14]]
# actual sorted output is
# [[ 1  1  1 10 12 12 14 14 17 18]]
# sorting done by RNN is
# [[ 1  1  1 10 12 12 14 14 17 18]]
#
#
# [[ 1 17  8  1 11  6 15 16 14  0]]
# actual sorted output is
# [[ 0  1  1  6  8 11 14 15 16 17]]
# sorting done by RNN is
# [[ 0  1  1  6  8 11 14 15 16 17]]
#
#
# [[ 9  2 12  9  2 14 18  4 13  6]]
# actual sorted output is
# [[ 2  2  4  6  9  9 12 13 14 18]]
# sorting done by RNN is
# [[ 2  2  4  6  9  9 12 13 14 18]]
#
#
# [[ 6 14 17  4  5  4 10 11  5 18]]
# actual sorted output is
# [[ 4  4  5  5  6 10 11 14 17 18]]
# sorting done by RNN is
# [[ 4  4  5  5  6 10 11 14 17 18]]
#
#
# [[ 4  1 13  2 11 18 17  1 16 10]]
# actual sorted output is
# [[ 1  1  2  4 10 11 13 16 17 18]]
# sorting done by RNN is
# [[ 1  1  2  4 10 11 13 16 17 18]]
#
#
# [[18  1 12 18 19 11 15 16 17  7]]
# actual sorted output is
# [[ 1  7 11 12 15 16 17 18 18 19]]
# sorting done by RNN is
# [[ 1  7 11 12 15 16 17 18 18 19]]
#
#
# [[15 16 17  4  5 13  2 10  8 19]]
# actual sorted output is
# [[ 2  4  5  8 10 13 15 16 17 19]]
# sorting done by RNN is
# [[ 2  4  5  8 10 13 15 16 17 19]]
#
#
# [[ 1 17 10 10  6  1  7  4  4  9]]
# actual sorted output is
# [[ 1  1  4  4  6  7  9 10 10 17]]
# sorting done by RNN is
# [[ 1  1  4  4  6  7  9 10 10 17]]
#
#
# [[19  8 12  7 11  5 10 16 11  8]]
# actual sorted output is
# [[ 5  7  8  8 10 11 11 12 16 19]]
# sorting done by RNN is
# [[ 5  7  8  8 10 11 11 12 16 19]]
#
#
# [[ 5  6 15 12  6  3 15  0 16 11]]
# actual sorted output is
# [[ 0  3  5  6  6 11 12 15 15 16]]
# sorting done by RNN is
# [[ 0  3  5  6  6 11 12 15 15 16]]
#
#
# [[ 1 12 13 19  2 14 19 10 16 15]]
# actual sorted output is
# [[ 1  2 10 12 13 14 15 16 19 19]]
# sorting done by RNN is
# [[ 1  2 10 12 13 14 15 16 19 19]]
#
#
# [[ 2  6 13  5  6 14 14  7  9  2]]
# actual sorted output is
# [[ 2  2  5  6  6  7  9 13 14 14]]
# sorting done by RNN is
# [[ 2  2  5  6  6  7  9 13 14 14]]
#
#
# [[18  7 13 18  6  5 18 19 18  2]]
# actual sorted output is
# [[ 2  5  6  7 13 18 18 18 18 19]]
# sorting done by RNN is
# [[ 2  5  6  7 13 18 18 18 18 19]]
#
#
# [[ 5  8 18  6  9  3 15 17  6  3]]
# actual sorted output is
# [[ 3  3  5  6  6  8  9 15 17 18]]
# sorting done by RNN is
# [[ 3  3  5  6  6  8  9 15 17 18]]
#
#
# [[10  3  9  5  9 15  6 19 12 15]]
# actual sorted output is
# [[ 3  5  6  9  9 10 12 15 15 19]]
# sorting done by RNN is
# [[ 3  5  6  9  9 10 12 15 15 19]]
#
#
# [[ 3  0 14 11  6  1  0 17  6  0]]
# actual sorted output is
# [[ 0  0  0  1  3  6  6 11 14 17]]
# sorting done by RNN is
# [[ 0  0  0  1  3  6  6 11 14 17]]
#
#
# [[ 5  5  0  3  2 19 16 12 14  1]]
# actual sorted output is
# [[ 0  1  2  3  5  5 12 14 16 19]]
# sorting done by RNN is
# [[ 0  1  2  3  5  5 12 14 16 19]]
#
#
# [[19  7 12  7 15 19 17 11  0  1]]
# actual sorted output is
# [[ 0  1  7  7 11 12 15 17 19 19]]
# sorting done by RNN is
# [[ 0  1  7  7 11 12 15 17 19 19]]
#
#
# [[ 7 18 19  6 12 16 14 17  9  3]]
# actual sorted output is
# [[ 3  6  7  9 12 14 16 17 18 19]]
# sorting done by RNN is
# [[ 3  6  7  9 12 14 16 17 18 19]]
#
#
# [[ 5  8 17 18 16 10 15  4 14  7]]
# actual sorted output is
# [[ 4  5  7  8 10 14 15 16 17 18]]
# sorting done by RNN is
# [[ 4  5  7  8 10 14 15 16 17 18]]
#
#
# [[ 2  5 18  4 10 18  3 10 14 11]]
# actual sorted output is
# [[ 2  3  4  5 10 10 11 14 18 18]]
# sorting done by RNN is
# [[ 2  3  4  5 10 10 11 14 18 18]]
#
#
# [[ 4  1 17  8  8  0 13 14 19  9]]
# actual sorted output is
# [[ 0  1  4  8  8  9 13 14 17 19]]
# sorting done by RNN is
# [[ 0  1  4  8  8  9 13 14 17 19]]
#
#
# [[ 5  6 10 10 19  6 18  6  4 12]]
# actual sorted output is
# [[ 4  5  6  6  6 10 10 12 18 19]]
# sorting done by RNN is
# [[ 4  5  6  6  6 10 10 12 18 19]]
#
#
# [[ 6 13  2  4  1 18 17  7  3 17]]
# actual sorted output is
# [[ 1  2  3  4  6  7 13 17 17 18]]
# sorting done by RNN is
# [[ 1  2  3  4  6  7 13 17 17 18]]
#
#
# [[17  4 11 16  8 12 15 18 18 14]]
# actual sorted output is
# [[ 4  8 11 12 14 15 16 17 18 18]]
# sorting done by RNN is
# [[ 4  8 11 12 14 15 16 17 18 18]]
#
#
# [[17 16  1  1  6 14 19  8  6 13]]
# actual sorted output is
# [[ 1  1  6  6  8 13 14 16 17 19]]
# sorting done by RNN is
# [[ 1  1  6  6  8 13 14 16 17 19]]
#
#
# [[ 8 10 14 19 12  2  9 14 13  0]]
# actual sorted output is
# [[ 0  2  8  9 10 12 13 14 14 19]]
# sorting done by RNN is
# [[ 0  2  8  9 10 12 13 14 14 19]]
#
#
# [[19  9 17  0 10 15 12 13 14  1]]
# actual sorted output is
# [[ 0  1  9 10 12 13 14 15 17 19]]
# sorting done by RNN is
# [[ 0  1  9 10 12 13 14 15 17 19]]
#
#
# [[ 9  2 13  2 13  1  1 10 16  6]]
# actual sorted output is
# [[ 1  1  2  2  6  9 10 13 13 16]]
# sorting done by RNN is
# [[ 1  1  2  2  6  9 10 13 13 16]]
#
#
# [[10  8 14  9  2  9  3 17  7 13]]
# actual sorted output is
# [[ 2  3  7  8  9  9 10 13 14 17]]
# sorting done by RNN is
# [[ 2  3  7  8  9  9 10 13 14 17]]
#
#
# [[ 0 19  3 11  3 14 14  9  3  9]]
# actual sorted output is
# [[ 0  3  3  3  9  9 11 14 14 19]]
# sorting done by RNN is
# [[ 0  3  3  3  9  9 11 14 14 19]]
#
#
# [[18 10 18 17 17 12  8 14  2  9]]
# actual sorted output is
# [[ 2  8  9 10 12 14 17 17 18 18]]
# sorting done by RNN is
# [[ 2  8  9 10 12 14 17 17 18 18]]
#
#
# [[12  2 11 10 18 14  3  2 18  0]]
# actual sorted output is
# [[ 0  2  2  3 10 11 12 14 18 18]]
# sorting done by RNN is
# [[ 0  2  2  3 10 11 12 14 18 18]]
#
#
# [[11 18  8 15 19  3  4  8 13  3]]
# actual sorted output is
# [[ 3  3  4  8  8 11 13 15 18 19]]
# sorting done by RNN is
# [[ 3  3  4  8  8 11 13 15 18 19]]
#
#
# [[17  3 15  5  9 19  2 12 17  7]]
# actual sorted output is
# [[ 2  3  5  7  9 12 15 17 17 19]]
# sorting done by RNN is
# [[ 2  3  5  7  9 12 15 17 17 19]]
#
#
# [[18 14  4 18 14  8 11  6 12  8]]
# actual sorted output is
# [[ 4  6  8  8 11 12 14 14 18 18]]
# sorting done by RNN is
# [[ 4  6  8  8 11 12 14 14 18 18]]
#
#
# [[16 19 10 12  8 17 14  5  5 19]]
# actual sorted output is
# [[ 5  5  8 10 12 14 16 17 19 19]]
# sorting done by RNN is
# [[ 5  5  8 10 12 14 16 17 19 19]]
#
#
# [[10 14  6  0  8 15  0  3 12 16]]
# actual sorted output is
# [[ 0  0  3  6  8 10 12 14 15 16]]
# sorting done by RNN is
# [[ 0  0  3  6  8 10 12 14 15 16]]
#
#
# [[17 18  4 15  9  1  6 10  5 10]]
# actual sorted output is
# [[ 1  4  5  6  9 10 10 15 17 18]]
# sorting done by RNN is
# [[ 1  4  5  6  9 10 10 15 17 18]]
#
#
# [[ 7  2  7  0 15 11  3 10  3 19]]
# actual sorted output is
# [[ 0  2  3  3  7  7 10 11 15 19]]
# sorting done by RNN is
# [[ 0  2  3  3  7  7 10 11 15 19]]
#
#
# [[ 5  3  7 12 16 19  8  6  2  9]]
# actual sorted output is
# [[ 2  3  5  6  7  8  9 12 16 19]]
# sorting done by RNN is
# [[ 2  3  5  6  7  8  9 12 16 19]]
#
#
# [[15  3  6 11 17  1  1 16 19  2]]
# actual sorted output is
# [[ 1  1  2  3  6 11 15 16 17 19]]
# sorting done by RNN is
# [[ 1  1  2  3  6 11 15 16 17 19]]
#
#
# [[ 5 14  1  7 12  3 11 17  0 17]]
# actual sorted output is
# [[ 0  1  3  5  7 11 12 14 17 17]]
# sorting done by RNN is
# [[ 0  1  3  5  7 11 12 14 17 17]]
#
#
# [[19  5  5 19  5 19  8 12  2  3]]
# actual sorted output is
# [[ 2  3  5  5  5  8 12 19 19 19]]
# sorting done by RNN is
# [[ 2  3  5  5  5  8 12 19 19 19]]
#
#
# [[11 18  1 15  9 10  6 10 16 13]]
# actual sorted output is
# [[ 1  6  9 10 10 11 13 15 16 18]]
# sorting done by RNN is
# [[ 1  6  9 10 10 11 13 15 16 18]]
#
#
# [[11 19 19 14 14 19  6 17  6 18]]
# actual sorted output is
# [[ 6  6 11 14 14 17 18 19 19 19]]
# sorting done by RNN is
# [[ 6  6 11 14 14 17 18 19 19 19]]
#
#
# [[ 2  9  9 14 19 18  1 17 16  5]]
# actual sorted output is
# [[ 1  2  5  9  9 14 16 17 18 19]]
# sorting done by RNN is
# [[ 1  2  5  9  9 14 16 17 18 19]]
#
#
# [[ 1  7 18 12  7 10 16  4 14  6]]
# actual sorted output is
# [[ 1  4  6  7  7 10 12 14 16 18]]
# sorting done by RNN is
# [[ 1  4  6  7  7 10 12 14 16 18]]
#
#
# [[14 11  7  2  2 19 12  5 18  5]]
# actual sorted output is
# [[ 2  2  5  5  7 11 12 14 18 19]]
# sorting done by RNN is
# [[ 2  2  5  5  7 11 12 14 18 19]]
#
#
# [[ 8 14  0  8  8 17  5 19 17 11]]
# actual sorted output is
# [[ 0  5  8  8  8 11 14 17 17 19]]
# sorting done by RNN is
# [[ 0  5  8  8  8 11 14 17 17 19]]
#
#
# [[ 2  4  3 10  2  6 13 15  0  3]]
# actual sorted output is
# [[ 0  2  2  3  3  4  6 10 13 15]]
# sorting done by RNN is
# [[ 0  2  2  3  3  4  6 10 13 15]]
#
#
# [[14  3 14  1  1 17 15 16 16 14]]
# actual sorted output is
# [[ 1  1  3 14 14 14 15 16 16 17]]
# sorting done by RNN is
# [[ 1  1  3 14 14 14 15 16 16 17]]
#
#
# [[13 13  6  4 10 16  8  0 16  3]]
# actual sorted output is
# [[ 0  3  4  6  8 10 13 13 16 16]]
# sorting done by RNN is
# [[ 0  3  4  6  8 10 13 13 16 16]]
#
#
# [[11 13 16  7  2 11 18  8 12  7]]
# actual sorted output is
# [[ 2  7  7  8 11 11 12 13 16 18]]
# sorting done by RNN is
# [[ 2  7  7  8 11 11 12 13 16 18]]
#
#
# [[ 3  4  0  0  8  2  3 18 14 11]]
# actual sorted output is
# [[ 0  0  2  3  3  4  8 11 14 18]]
# sorting done by RNN is
# [[ 0  0  2  3  3  4  8 11 14 18]]
#
#
# [[10  3 11  2 17 13 18  7  1 19]]
# actual sorted output is
# [[ 1  2  3  7 10 11 13 17 18 19]]
# sorting done by RNN is
# [[ 1  2  3  7 10 11 13 17 18 19]]
#
#
# [[ 0 14 11  3 15 13  4 11  9  4]]
# actual sorted output is
# [[ 0  3  4  4  9 11 11 13 14 15]]
# sorting done by RNN is
# [[ 0  3  4  4  9 11 11 13 14 15]]
#
#
# [[12 16  9 17  8 13 17  6 15  1]]
# actual sorted output is
# [[ 1  6  8  9 12 13 15 16 17 17]]
# sorting done by RNN is
# [[ 1  6  8  9 12 13 15 16 17 17]]
#
#
# [[19  6 18 10  6 18 13  7 16 14]]
# actual sorted output is
# [[ 6  6  7 10 13 14 16 18 18 19]]
# sorting done by RNN is
# [[ 6  6  7 10 13 14 16 18 18 19]]
#
#
# [[17  0  5  2  1 13 12  0 11 18]]
# actual sorted output is
# [[ 0  0  1  2  5 11 12 13 17 18]]
# sorting done by RNN is
# [[ 0  0  1  2  5 11 12 13 17 18]]
#
#
# [[ 1  4  2 18  8  0  2  3 17 15]]
# actual sorted output is
# [[ 0  1  2  2  3  4  8 15 17 18]]
# sorting done by RNN is
# [[ 0  1  2  2  3  4  8 15 17 18]]
#
#
# [[ 8 18 15 19  0 15  7 16 17 17]]
# actual sorted output is
# [[ 0  7  8 15 15 16 17 17 18 19]]
# sorting done by RNN is
# [[ 0  7  8 15 15 16 17 17 18 19]]
#
#
# [[ 7 13 10  5 18 10  2 18 12 19]]
# actual sorted output is
# [[ 2  5  7 10 10 12 13 18 18 19]]
# sorting done by RNN is
# [[ 2  5  7 10 10 12 13 18 18 19]]
#
#
# [[17  8 13  6 13  5  2  4  1 17]]
# actual sorted output is
# [[ 1  2  4  5  6  8 13 13 17 17]]
# sorting done by RNN is
# [[ 1  2  4  5  6  8 13 13 17 17]]
#
#
# [[12 10  6 12  0 10 18  1 12  6]]
# actual sorted output is
# [[ 0  1  6  6 10 10 12 12 12 18]]
# sorting done by RNN is
# [[ 0  1  6  6 10 10 12 12 12 18]]
#
#
# [[18 18  0  9  7 17 13  9  4  5]]
# actual sorted output is
# [[ 0  4  5  7  9  9 13 17 18 18]]
# sorting done by RNN is
# [[ 0  4  5  7  9  9 13 17 18 18]]
#
#
# [[ 6  1  0 12  9 17 14 17  3 18]]
# actual sorted output is
# [[ 0  1  3  6  9 12 14 17 17 18]]
# sorting done by RNN is
# [[ 0  1  3  6  9 12 14 17 17 18]]
#
#
# [[ 6 16 12  8  4 17  6  4  2 13]]
# actual sorted output is
# [[ 2  4  4  6  6  8 12 13 16 17]]
# sorting done by RNN is
# [[ 2  4  4  6  6  8 12 13 16 17]]
#
#
# [[17  9  7 13  4 19 19 16 18  0]]
# actual sorted output is
# [[ 0  4  7  9 13 16 17 18 19 19]]
# sorting done by RNN is
# [[ 0  4  7  9 13 16 17 18 19 19]]
#
#
# [[ 5  2  6 19 11 10 18  5 15 12]]
# actual sorted output is
# [[ 2  5  5  6 10 11 12 15 18 19]]
# sorting done by RNN is
# [[ 2  5  5  6 10 11 12 15 18 19]]
#
#
# [[ 7  9 15 10 17 15 15 18 15  6]]
# actual sorted output is
# [[ 6  7  9 10 15 15 15 15 17 18]]
# sorting done by RNN is
# [[ 6  7  9 10 15 15 15 15 17 18]]
#
#
# [[ 7  0 14 19 13 14  5 17 10  9]]
# actual sorted output is
# [[ 0  5  7  9 10 13 14 14 17 19]]
# sorting done by RNN is
# [[ 0  5  7  9 10 13 14 14 17 19]]
#
#
# [[19 11 11 17 16  0  7 17 12  1]]
# actual sorted output is
# [[ 0  1  7 11 11 12 16 17 17 19]]
# sorting done by RNN is
# [[ 0  1  7 11 11 12 16 17 17 19]]
#
#
# [[ 0  1 15  3 15  1  7  0  2 19]]
# actual sorted output is
# [[ 0  0  1  1  2  3  7 15 15 19]]
# sorting done by RNN is
# [[ 0  0  1  1  2  3  7 15 15 19]]
#
#
# [[19 10 13  0 18  9  6 10  5  5]]
# actual sorted output is
# [[ 0  5  5  6  9 10 10 13 18 19]]
# sorting done by RNN is
# [[ 0  5  5  6  9 10 10 13 18 19]]
#
#
# [[19  0  2  8  0 11 19  4  0  6]]
# actual sorted output is
# [[ 0  0  0  2  4  6  8 11 19 19]]
# sorting done by RNN is
# [[ 0  0  0  2  4  6  8 11 19 19]]
#
#
# [[11  4 10 15 17  0  3  1  7 15]]
# actual sorted output is
# [[ 0  1  3  4  7 10 11 15 15 17]]
# sorting done by RNN is
# [[ 0  1  3  4  7 10 11 15 15 17]]
#
#
# [[ 9 15  7 13  7 12 15  6  1  8]]
# actual sorted output is
# [[ 1  6  7  7  8  9 12 13 15 15]]
# sorting done by RNN is
# [[ 1  6  7  7  8  9 12 13 15 15]]
#
#
# [[12 14 17 14  0  1 17 17 18 13]]
# actual sorted output is
# [[ 0  1 12 13 14 14 17 17 17 18]]
# sorting done by RNN is
# [[ 0  1 12 13 14 14 17 17 17 18]]
#
#
# [[19 11 17  3 15  5 14 10  1  6]]
# actual sorted output is
# [[ 1  3  5  6 10 11 14 15 17 19]]
# sorting done by RNN is
# [[ 1  3  5  6 10 11 14 15 17 19]]
#
#
# [[17  6 15  2  6  6 17 15 12 12]]
# actual sorted output is
# [[ 2  6  6  6 12 12 15 15 17 17]]
# sorting done by RNN is
# [[ 2  6  6  6 12 12 15 15 17 17]]
#
#
# [[ 9  4 15 10  6 13  5 12  1 19]]
# actual sorted output is
# [[ 1  4  5  6  9 10 12 13 15 19]]
# sorting done by RNN is
# [[ 1  4  5  6  9 10 12 13 15 19]]
#
#
# [[ 7  3 14 14 12 19  8  3  4 13]]
# actual sorted output is
# [[ 3  3  4  7  8 12 13 14 14 19]]
# sorting done by RNN is
# [[ 3  3  4  7  8 12 13 14 14 19]]
#
#
# [[ 4 10  7  7 18  1 19 13  2 12]]
# actual sorted output is
# [[ 1  2  4  7  7 10 12 13 18 19]]
# sorting done by RNN is
# [[ 1  2  4  7  7 10 12 13 18 19]]
#
#
# [[ 4 18 14  5  3  7 17  3  6 18]]
# actual sorted output is
# [[ 3  3  4  5  6  7 14 17 18 18]]
# sorting done by RNN is
# [[ 3  3  4  5  6  7 14 17 18 18]]
#
#
# [[10 10  8  1  6  9  6  4  6  1]]
# actual sorted output is
# [[ 1  1  4  6  6  6  8  9 10 10]]
# sorting done by RNN is
# [[ 1  1  4  6  6  6  8  9 10 10]]
#
#
# [[12  5  7  1 17  7  5 12 13 15]]
# actual sorted output is
# [[ 1  5  5  7  7 12 12 13 15 17]]
# sorting done by RNN is
# [[ 1  5  5  7  7 12 12 13 15 17]]
#
#
# [[17  2 13  0 11  1  9 17  5  8]]
# actual sorted output is
# [[ 0  1  2  5  8  9 11 13 17 17]]
# sorting done by RNN is
# [[ 0  1  2  5  8  9 11 13 17 17]]
#
#
# [[11 18  3  9  8 18 15  6 14 18]]
# actual sorted output is
# [[ 3  6  8  9 11 14 15 18 18 18]]
# sorting done by RNN is
# [[ 3  6  8  9 11 14 15 18 18 18]]
#
#
# [[ 2 15 17  7  0  3 11 10 15  6]]
# actual sorted output is
# [[ 0  2  3  6  7 10 11 15 15 17]]
# sorting done by RNN is
# [[ 0  2  3  6  7 10 11 15 15 17]]
#
#
# [[ 4  2  7  6 19  7 19 14  5 10]]
# actual sorted output is
# [[ 2  4  5  6  7  7 10 14 19 19]]
# sorting done by RNN is
# [[ 2  4  5  6  7  7 10 14 19 19]]
#
#
# [[12 17 13  9 14 17  3 14  8 11]]
# actual sorted output is
# [[ 3  8  9 11 12 13 14 14 17 17]]
# sorting done by RNN is
# [[ 3  8  9 11 12 13 14 14 17 17]]
#
#
# [[16 15  2 15 14  1  4 19  4 11]]
# actual sorted output is
# [[ 1  2  4  4 11 14 15 15 16 19]]
# sorting done by RNN is
# [[ 1  2  4  4 11 14 15 15 16 19]]
#
#
# [[13  3  8 19  4 17  9  4 16 12]]
# actual sorted output is
# [[ 3  4  4  8  9 12 13 16 17 19]]
# sorting done by RNN is
# [[ 3  4  4  8  9 12 13 16 17 19]]
#
#
# [[17  6  8 12  0 14 15  4  0 11]]
# actual sorted output is
# [[ 0  0  4  6  8 11 12 14 15 17]]
# sorting done by RNN is
# [[ 0  0  4  6  8 11 12 14 15 17]]
#
#
# [[10 19 18  2  2  5 16  9  6 10]]
# actual sorted output is
# [[ 2  2  5  6  9 10 10 16 18 19]]
# sorting done by RNN is
# [[ 2  2  5  6  9 10 10 16 18 19]]
#
#
# [[19 10 17 13  1 17 16  8 10 11]]
# actual sorted output is
# [[ 1  8 10 10 11 13 16 17 17 19]]
# sorting done by RNN is
# [[ 1  8 10 10 11 13 16 17 17 19]]
#
#
# [[16 14  0  2 13 16 11 16  1 11]]
# actual sorted output is
# [[ 0  1  2 11 11 13 14 16 16 16]]
# sorting done by RNN is
# [[ 0  1  2 11 11 13 14 16 16 16]]
#
#
# [[ 3 14 11 15  2 18 16  5 11 13]]
# actual sorted output is
# [[ 2  3  5 11 11 13 14 15 16 18]]
# sorting done by RNN is
# [[ 2  3  5 11 11 13 14 15 16 18]]
#
#
# [[14 11 12  2  8  7  6  3  6  9]]
# actual sorted output is
# [[ 2  3  6  6  7  8  9 11 12 14]]
# sorting done by RNN is
# [[ 2  3  6  6  7  8  9 11 12 14]]
#
#
# [[14 10 10 15  9  0 17  2 18  8]]
# actual sorted output is
# [[ 0  2  8  9 10 10 14 15 17 18]]
# sorting done by RNN is
# [[ 0  2  8  9 10 10 14 15 17 18]]
#
#
# [[ 8 12 16 16  5  2 14 18 11  0]]
# actual sorted output is
# [[ 0  2  5  8 11 12 14 16 16 18]]
# sorting done by RNN is
# [[ 0  2  5  8 11 12 14 16 16 18]]
#
#
# [[13 18 10 13  2  6 16 18 17  6]]
# actual sorted output is
# [[ 2  6  6 10 13 13 16 17 18 18]]
# sorting done by RNN is
# [[ 2  6  6 10 13 13 16 17 18 18]]
#
#
# [[ 2 18  7 18  8 10  9  4 17 17]]
# actual sorted output is
# [[ 2  4  7  8  9 10 17 17 18 18]]
# sorting done by RNN is
# [[ 2  4  7  8  9 10 17 17 18 18]]
#
#
# [[ 9  1  3  1  0  0  6 17  1 11]]
# actual sorted output is
# [[ 0  0  1  1  1  3  6  9 11 17]]
# sorting done by RNN is
# [[ 0  0  1  1  1  3  6  9 11 17]]
#
#
# [[ 0 17  8  9 11 18  3 16 17  2]]
# actual sorted output is
# [[ 0  2  3  8  9 11 16 17 17 18]]
# sorting done by RNN is
# [[ 0  2  3  8  9 11 16 17 17 18]]
#
#
# [[14  1  1 19  4 12  7  9  6 14]]
# actual sorted output is
# [[ 1  1  4  6  7  9 12 14 14 19]]
# sorting done by RNN is
# [[ 1  1  4  6  7  9 12 14 14 19]]
#
#
# [[16 15 17  5  1 15 12  2  3  2]]
# actual sorted output is
# [[ 1  2  2  3  5 12 15 15 16 17]]
# sorting done by RNN is
# [[ 1  2  2  3  5 12 15 15 16 17]]
#
#
# [[12  2  8  4  2  7 16  9 16  1]]
# actual sorted output is
# [[ 1  2  2  4  7  8  9 12 16 16]]
# sorting done by RNN is
# [[ 1  2  2  4  7  8  9 12 16 16]]
#
#
# [[ 4  5 12  5 18  0  2 17  1  3]]
# actual sorted output is
# [[ 0  1  2  3  4  5  5 12 17 18]]
# sorting done by RNN is
# [[ 0  1  2  3  4  5  5 12 17 18]]
#
#
# [[ 0 17  8 14 11  9  6 11 10  1]]
# actual sorted output is
# [[ 0  1  6  8  9 10 11 11 14 17]]
# sorting done by RNN is
# [[ 0  1  6  8  9 10 11 11 14 17]]
#
#
# [[16 12 12  5  8  2  0 11 19 12]]
# actual sorted output is
# [[ 0  2  5  8 11 12 12 12 16 19]]
# sorting done by RNN is
# [[ 0  2  5  8 11 12 12 12 16 19]]
#
#
# [[ 3 15  6 14  1 18  7  5  0  4]]
# actual sorted output is
# [[ 0  1  3  4  5  6  7 14 15 18]]
# sorting done by RNN is
# [[ 0  1  3  4  5  6  7 14 15 18]]
#
#
# [[ 5 12  7  7  0 19 11  6 15  7]]
# actual sorted output is
# [[ 0  5  6  7  7  7 11 12 15 19]]
# sorting done by RNN is
# [[ 0  5  6  7  7  7 11 12 15 19]]
#
#
# [[11  8  5 12 12 10 11 15 17  0]]
# actual sorted output is
# [[ 0  5  8 10 11 11 12 12 15 17]]
# sorting done by RNN is
# [[ 0  5  8 10 11 11 12 12 15 17]]
#
#
# [[12  5 19  0  9 15 12  6  4 16]]
# actual sorted output is
# [[ 0  4  5  6  9 12 12 15 16 19]]
# sorting done by RNN is
# [[ 0  4  5  6  9 12 12 15 16 19]]
#
#
# [[ 6 15 10  5 18 14  1  2  2 11]]
# actual sorted output is
# [[ 1  2  2  5  6 10 11 14 15 18]]
# sorting done by RNN is
# [[ 1  2  2  5  6 10 11 14 15 18]]
#
#
# [[18 11  0  1  6  6  7  3 17  0]]
# actual sorted output is
# [[ 0  0  1  3  6  6  7 11 17 18]]
# sorting done by RNN is
# [[ 0  0  1  3  6  6  7 11 17 18]]
#
#
# [[ 7  8 10  0  4 10 11 16  1 13]]
# actual sorted output is
# [[ 0  1  4  7  8 10 10 11 13 16]]
# sorting done by RNN is
# [[ 0  1  4  7  8 10 10 11 13 16]]
#
#
# [[13 17  2  3  4 19 12 11  7 18]]
# actual sorted output is
# [[ 2  3  4  7 11 12 13 17 18 19]]
# sorting done by RNN is
# [[ 2  3  4  7 11 12 13 17 18 19]]
#
#
# [[16  3 19 17  5  9  2 15 14 15]]
# actual sorted output is
# [[ 2  3  5  9 14 15 15 16 17 19]]
# sorting done by RNN is
# [[ 2  3  5  9 14 15 15 16 17 19]]
#
#
# [[12  7  1 18  2 18 14  3  6  9]]
# actual sorted output is
# [[ 1  2  3  6  7  9 12 14 18 18]]
# sorting done by RNN is
# [[ 1  2  3  6  7  9 12 14 18 18]]
#
#
# [[ 4 12  0  6  1 18  0  4  0 12]]
# actual sorted output is
# [[ 0  0  0  1  4  4  6 12 12 18]]
# sorting done by RNN is
# [[ 0  0  0  1  4  4  6 12 12 18]]
#
#
# [[ 2  5 18 12 16  6 17 12 10  5]]
# actual sorted output is
# [[ 2  5  5  6 10 12 12 16 17 18]]
# sorting done by RNN is
# [[ 2  5  5  6 10 12 12 16 17 18]]
#
#
# [[12 11  4 15  6 17  6 17 14  4]]
# actual sorted output is
# [[ 4  4  6  6 11 12 14 15 17 17]]
# sorting done by RNN is
# [[ 4  4  6  6 11 12 14 15 17 17]]
#
#
# [[ 7 18  6 18  1  1 17 13  1 14]]
# actual sorted output is
# [[ 1  1  1  6  7 13 14 17 18 18]]
# sorting done by RNN is
# [[ 1  1  1  6  7 13 14 17 18 18]]
#
#
# [[11  6  5  2 18 11  6 19  8 10]]
# actual sorted output is
# [[ 2  5  6  6  8 10 11 11 18 19]]
# sorting done by RNN is
# [[ 2  5  6  6  8 10 11 11 18 19]]
#
#
# [[17  5  9  2  2  4 18  9 18  3]]
# actual sorted output is
# [[ 2  2  3  4  5  9  9 17 18 18]]
# sorting done by RNN is
# [[ 2  2  3  4  5  9  9 17 18 18]]
#
#
# [[ 3  2 13  9 14  8  9 10 17  6]]
# actual sorted output is
# [[ 2  3  6  8  9  9 10 13 14 17]]
# sorting done by RNN is
# [[ 2  3  6  8  9  9 10 13 14 17]]
#
#
# [[ 2 13  1  4  6  1 15 13 13  9]]
# actual sorted output is
# [[ 1  1  2  4  6  9 13 13 13 15]]
# sorting done by RNN is
# [[ 1  1  2  4  6  9 13 13 13 15]]
#
#
# [[ 3  0 16  0  6  3  1 11  2 18]]
# actual sorted output is
# [[ 0  0  1  2  3  3  6 11 16 18]]
# sorting done by RNN is
# [[ 0  0  1  2  3  3  6 11 16 18]]
#
#
# [[ 8 17  1  7  9 17 18 15 13  6]]
# actual sorted output is
# [[ 1  6  7  8  9 13 15 17 17 18]]
# sorting done by RNN is
# [[ 1  6  7  8  9 13 15 17 17 18]]
#
#
# [[ 8 12 18  3 18 18 18  3  2  1]]
# actual sorted output is
# [[ 1  2  3  3  8 12 18 18 18 18]]
# sorting done by RNN is
# [[ 1  2  3  3  8 12 18 18 18 18]]
#
#
# [[15  0  2  0  2  1 18 18 17  6]]
# actual sorted output is
# [[ 0  0  1  2  2  6 15 17 18 18]]
# sorting done by RNN is
# [[ 0  0  1  2  2  6 15 17 18 18]]
#
#
# [[10 12 10 18 10  1  3  5 18 11]]
# actual sorted output is
# [[ 1  3  5 10 10 10 11 12 18 18]]
# sorting done by RNN is
# [[ 1  3  5 10 10 10 11 12 18 18]]
#
#
# [[ 8  7  4 18  5  7  4  6 16  5]]
# actual sorted output is
# [[ 4  4  5  5  6  7  7  8 16 18]]
# sorting done by RNN is
# [[ 4  4  5  5  6  7  8 16 16 18]]
#
#
# [[19 13  6  7 10 17 13  8  2 18]]
# actual sorted output is
# [[ 2  6  7  8 10 13 13 17 18 19]]
# sorting done by RNN is
# [[ 2  6  7  8 10 13 13 17 18 19]]
#
#
# [[13 10 16  1 10  6  9  1  8 12]]
# actual sorted output is
# [[ 1  1  6  8  9 10 10 12 13 16]]
# sorting done by RNN is
# [[ 1  1  6  8  9 10 10 12 13 16]]
#
#
# [[ 9 17  6  4 14  6  8  7 13 15]]
# actual sorted output is
# [[ 4  6  6  7  8  9 13 14 15 17]]
# sorting done by RNN is
# [[ 4  6  6  7  8  9 13 14 15 17]]
#
#
# [[14  7  8 11 10 14 14 12 19 14]]
# actual sorted output is
# [[ 7  8 10 11 12 14 14 14 14 19]]
# sorting done by RNN is
# [[ 7  8 10 11 12 14 14 14 14 19]]
#
#
# [[ 5 11  9  9 11  2 13  4 12  9]]
# actual sorted output is
# [[ 2  4  5  9  9  9 11 11 12 13]]
# sorting done by RNN is
# [[ 2  4  5  9  9  9 11 11 12 13]]
#
#
# [[18 11 12  1 18 11  5  0 14 19]]
# actual sorted output is
# [[ 0  1  5 11 11 12 14 18 18 19]]
# sorting done by RNN is
# [[ 0  1  5 11 11 12 14 18 18 19]]
#
#
# [[13 12 17 12 19 11  3  9 18 15]]
# actual sorted output is
# [[ 3  9 11 12 12 13 15 17 18 19]]
# sorting done by RNN is
# [[ 3  9 11 12 12 13 15 17 18 19]]
#
#
# [[ 7 18 15  2 15 12  6 13  7 10]]
# actual sorted output is
# [[ 2  6  7  7 10 12 13 15 15 18]]
# sorting done by RNN is
# [[ 2  6  7  7 10 12 13 15 15 18]]
#
#
# [[19 15 13 19  7 15 14  0 13 14]]
# actual sorted output is
# [[ 0  7 13 13 14 14 15 15 19 19]]
# sorting done by RNN is
# [[ 0  7 13 13 14 14 15 15 19 19]]
#
#
# [[11 14  8 14  0  9 18 14 12 19]]
# actual sorted output is
# [[ 0  8  9 11 12 14 14 14 18 19]]
# sorting done by RNN is
# [[ 0  8  9 11 12 14 14 14 18 19]]
#
#
# [[ 7 16  4  0  5 18  0 17  2  8]]
# actual sorted output is
# [[ 0  0  2  4  5  7  8 16 17 18]]
# sorting done by RNN is
# [[ 0  0  2  4  5  7  8 16 17 18]]
#
#
# [[ 0 13 10  3  1 19 12 14 10 18]]
# actual sorted output is
# [[ 0  1  3 10 10 12 13 14 18 19]]
# sorting done by RNN is
# [[ 0  1  3 10 10 12 13 14 18 19]]
#
#
# [[12  7  1 18  0  8 14 19  4 13]]
# actual sorted output is
# [[ 0  1  4  7  8 12 13 14 18 19]]
# sorting done by RNN is
# [[ 0  1  4  7  8 12 13 14 18 19]]
#
#
# [[10 15 15  9 13  3 10 17  9 10]]
# actual sorted output is
# [[ 3  9  9 10 10 10 13 15 15 17]]
# sorting done by RNN is
# [[ 3  9  9 10 10 10 13 15 15 17]]
#
#
# [[14  7  4 17  2  9 19  9 15  0]]
# actual sorted output is
# [[ 0  2  4  7  9  9 14 15 17 19]]
# sorting done by RNN is
# [[ 0  2  4  7  9  9 14 15 17 19]]
#
#
# [[ 4  5 17  1  8  7 17 17 19 19]]
# actual sorted output is
# [[ 1  4  5  7  8 17 17 17 19 19]]
# sorting done by RNN is
# [[ 1  4  5  7  8 17 17 17 19 19]]
#
#
# [[ 4  0 13  7 19  5  2 14 19 12]]
# actual sorted output is
# [[ 0  2  4  5  7 12 13 14 19 19]]
# sorting done by RNN is
# [[ 0  2  4  5  7 12 13 14 19 19]]
#
#
# [[ 8  2 19 15  1 13 10 16  4 10]]
# actual sorted output is
# [[ 1  2  4  8 10 10 13 15 16 19]]
# sorting done by RNN is
# [[ 1  2  4  8 10 10 13 15 16 19]]
#
#
# [[18 10 12 16 15 18 15  5 13  2]]
# actual sorted output is
# [[ 2  5 10 12 13 15 15 16 18 18]]
# sorting done by RNN is
# [[ 2  5 10 12 13 15 15 16 18 18]]
#
#
# [[10  8 15  5 14  1 12  5  2  3]]
# actual sorted output is
# [[ 1  2  3  5  5  8 10 12 14 15]]
# sorting done by RNN is
# [[ 1  2  3  5  5  8 10 12 14 15]]
#
#
# [[18 11 11  7  5 15 16  5 10 14]]
# actual sorted output is
# [[ 5  5  7 10 11 11 14 15 16 18]]
# sorting done by RNN is
# [[ 5  5  7 10 11 11 14 15 16 18]]
#
#
# [[12  9 18 17 10  3 16 16 16 16]]
# actual sorted output is
# [[ 3  9 10 12 16 16 16 16 17 18]]
# sorting done by RNN is
# [[ 3  9 10 12 16 16 16 16 17 18]]
#
#
# [[19 17 10  5 10 14  9  2 10 16]]
# actual sorted output is
# [[ 2  5  9 10 10 10 14 16 17 19]]
# sorting done by RNN is
# [[ 2  5  9 10 10 10 14 16 17 19]]
#
#
# [[12 17  3 18  2 13  5  1  9  8]]
# actual sorted output is
# [[ 1  2  3  5  8  9 12 13 17 18]]
# sorting done by RNN is
# [[ 1  2  3  5  8  9 12 13 17 18]]
#
#
# [[16  3  6  9  7 16 18 19  0 18]]
# actual sorted output is
# [[ 0  3  6  7  9 16 16 18 18 19]]
# sorting done by RNN is
# [[ 0  3  6  7  9 16 16 18 18 19]]
#
#
# [[14  8  2  8  7  0  1  1  2  8]]
# actual sorted output is
# [[ 0  1  1  2  2  7  8  8  8 14]]
# sorting done by RNN is
# [[ 0  1  1  2  2  7  8  8 14 14]]
#
#
# [[ 3 13  2  6  5 19 10  2  0  6]]
# actual sorted output is
# [[ 0  2  2  3  5  6  6 10 13 19]]
# sorting done by RNN is
# [[ 0  2  2  3  5  6  6 10 13 19]]
#
#
# [[ 6 11 18  7  2 18  2 15 15  3]]
# actual sorted output is
# [[ 2  2  3  6  7 11 15 15 18 18]]
# sorting done by RNN is
# [[ 2  2  3  6  7 11 15 15 18 18]]
#
#
# [[ 5 15  5  7 16  7 13 10 11  6]]
# actual sorted output is
# [[ 5  5  6  7  7 10 11 13 15 16]]
# sorting done by RNN is
# [[ 5  5  6  7  7 10 11 13 15 16]]
#
#
# [[17 10 15 17  4  5  6 16 12 16]]
# actual sorted output is
# [[ 4  5  6 10 12 15 16 16 17 17]]
# sorting done by RNN is
# [[ 4  5  6 10 12 15 16 16 17 17]]
#
#
# [[13 13 11 13 17  0 14  3 14 17]]
# actual sorted output is
# [[ 0  3 11 13 13 13 14 14 17 17]]
# sorting done by RNN is
# [[ 0  3 11 13 13 13 14 14 17 17]]
#
#
# [[ 4  6 11 16 18  5  3 13  6 16]]
# actual sorted output is
# [[ 3  4  5  6  6 11 13 16 16 18]]
# sorting done by RNN is
# [[ 3  4  5  6  6 11 13 16 16 18]]
#
#
# [[19 16  3  0  1 19  0 16  7 16]]
# actual sorted output is
# [[ 0  0  1  3  7 16 16 16 19 19]]
# sorting done by RNN is
# [[ 0  0  1  3  7 16 16 16 19 19]]
#
#
# [[15  2 14  3 14 19 14  4 10 14]]
# actual sorted output is
# [[ 2  3  4 10 14 14 14 14 15 19]]
# sorting done by RNN is
# [[ 2  3  4 10 14 14 14 14 15 19]]
#
#
# [[ 5  6  1  6 12  5  2 18  9 13]]
# actual sorted output is
# [[ 1  2  5  5  6  6  9 12 13 18]]
# sorting done by RNN is
# [[ 1  2  5  5  6  6  9 12 13 18]]
#
#
# [[ 4 12  5  3  3 10 13  0 12  7]]
# actual sorted output is
# [[ 0  3  3  4  5  7 10 12 12 13]]
# sorting done by RNN is
# [[ 0  3  3  4  5  7 10 12 12 13]]
#
#
# [[ 2 19 14  8  4  3 15  3 14 14]]
# actual sorted output is
# [[ 2  3  3  4  8 14 14 14 15 19]]
# sorting done by RNN is
# [[ 2  3  3  4  8 14 14 14 15 19]]
#
#
# [[14  8  9  5  7  9 16  0 19  9]]
# actual sorted output is
# [[ 0  5  7  8  9  9  9 14 16 19]]
# sorting done by RNN is
# [[ 0  5  7  8  9  9  9 14 16 19]]
#
#
# [[13  5  7 10 11 11 12  4  8 19]]
# actual sorted output is
# [[ 4  5  7  8 10 11 11 12 13 19]]
# sorting done by RNN is
# [[ 4  5  7  8 10 11 11 12 13 19]]
#
#
# [[ 7 14  6 15  6  7 18  2  2  5]]
# actual sorted output is
# [[ 2  2  5  6  6  7  7 14 15 18]]
# sorting done by RNN is
# [[ 2  2  5  6  6  7  7 14 15 18]]
#
#
# [[17 11  5 10 19  2 18  9  4 18]]
# actual sorted output is
# [[ 2  4  5  9 10 11 17 18 18 19]]
# sorting done by RNN is
# [[ 2  4  5  9 10 11 17 18 18 19]]
#
#
# [[19  8 18  5  0 19 11 12  0 11]]
# actual sorted output is
# [[ 0  0  5  8 11 11 12 18 19 19]]
# sorting done by RNN is
# [[ 0  0  5  8 11 11 12 18 19 19]]
#
#
# [[16  5 19 19  3  7  2  2 12  0]]
# actual sorted output is
# [[ 0  2  2  3  5  7 12 16 19 19]]
# sorting done by RNN is
# [[ 0  2  2  3  5  7 12 16 19 19]]
#
#
# [[17  3  7 18  3 11 18 14  7 11]]
# actual sorted output is
# [[ 3  3  7  7 11 11 14 17 18 18]]
# sorting done by RNN is
# [[ 3  3  7  7 11 11 14 17 18 18]]
#
#
# [[11  9 15 18  4  4  8  0  9  2]]
# actual sorted output is
# [[ 0  2  4  4  8  9  9 11 15 18]]
# sorting done by RNN is
# [[ 0  2  4  4  8  9  9 11 15 18]]
#
#
# [[ 3  6  1  5  7 12 15 19 10  2]]
# actual sorted output is
# [[ 1  2  3  5  6  7 10 12 15 19]]
# sorting done by RNN is
# [[ 1  2  3  5  6  7 10 12 15 19]]
#
#
# [[19 15 10  2 13 18  8  4 12 17]]
# actual sorted output is
# [[ 2  4  8 10 12 13 15 17 18 19]]
# sorting done by RNN is
# [[ 2  4  8 10 12 13 15 17 18 19]]
#
#
# [[ 1  0  1 18 12  9  0 18 18  3]]
# actual sorted output is
# [[ 0  0  1  1  3  9 12 18 18 18]]
# sorting done by RNN is
# [[ 0  0  1  1  3  9 12 18 18 18]]
#
#
# [[ 8 14 13 12 19 19  9 17  6  8]]
# actual sorted output is
# [[ 6  8  8  9 12 13 14 17 19 19]]
# sorting done by RNN is
# [[ 6  8  8  9 12 13 14 17 19 19]]
#
#
# [[ 3  3 19 18  4 14 15 17  7 13]]
# actual sorted output is
# [[ 3  3  4  7 13 14 15 17 18 19]]
# sorting done by RNN is
# [[ 3  3  4  7 13 14 15 17 18 19]]
#
#
# [[ 1 14  4  9 11 10 12 16 16 14]]
# actual sorted output is
# [[ 1  4  9 10 11 12 14 14 16 16]]
# sorting done by RNN is
# [[ 1  4  9 10 11 12 14 14 16 16]]
#
#
# [[ 2  0  7  4  0 12 11 13  4  3]]
# actual sorted output is
# [[ 0  0  2  3  4  4  7 11 12 13]]
# sorting done by RNN is
# [[ 0  0  2  3  4  4 11 12 13 19]]
#
#
# [[18  9  2  1  9 14 19  1  9 13]]
# actual sorted output is
# [[ 1  1  2  9  9  9 13 14 18 19]]
# sorting done by RNN is
# [[ 1  1  2  9  9  9 13 14 18 19]]
#
#
# [[ 8 12  6 12 12 16 15 12 14  6]]
# actual sorted output is
# [[ 6  6  8 12 12 12 12 14 15 16]]
# sorting done by RNN is
# [[ 6  6  8 12 12 12 12 14 15 16]]
#
#
# [[10  0 14  5  2  2 17 13 19  8]]
# actual sorted output is
# [[ 0  2  2  5  8 10 13 14 17 19]]
# sorting done by RNN is
# [[ 0  2  2  5  8 10 13 14 17 19]]
#
#
# [[16  5 10 14 14  3 19 12 11  7]]
# actual sorted output is
# [[ 3  5  7 10 11 12 14 14 16 19]]
# sorting done by RNN is
# [[ 3  5  7 10 11 12 14 14 16 19]]
#
#
# [[10  1 17 14 16  2 18 17 14  7]]
# actual sorted output is
# [[ 1  2  7 10 14 14 16 17 17 18]]
# sorting done by RNN is
# [[ 1  2  7 10 14 14 16 17 17 18]]
#
#
# [[11 19  9 16  4 19 18  0 19 14]]
# actual sorted output is
# [[ 0  4  9 11 14 16 18 19 19 19]]
# sorting done by RNN is
# [[ 0  4  9 11 14 16 18 19 19 19]]
#
#
# [[ 8 12  4  9  8  1 19 16  7  1]]
# actual sorted output is
# [[ 1  1  4  7  8  8  9 12 16 19]]
# sorting done by RNN is
# [[ 1  1  4  7  8  8  9 12 16 19]]
#
#
# [[10  9 15  1 13 13 14  3  8  2]]
# actual sorted output is
# [[ 1  2  3  8  9 10 13 13 14 15]]
# sorting done by RNN is
# [[ 1  2  3  8  9 10 13 13 14 15]]
#
#
# [[13  4 17  8  1  4  8 14  9 15]]
# actual sorted output is
# [[ 1  4  4  8  8  9 13 14 15 17]]
# sorting done by RNN is
# [[ 1  4  4  8  8  9 13 14 15 17]]
#
#
# [[ 6 10 10 16 12 16  8  4  7  8]]
# actual sorted output is
# [[ 4  6  7  8  8 10 10 12 16 16]]
# sorting done by RNN is
# [[ 4  6  7  8  8 10 10 12 16 16]]
#
#
# [[18  4  3  4 14  2 16 17 17 14]]
# actual sorted output is
# [[ 2  3  4  4 14 14 16 17 17 18]]
# sorting done by RNN is
# [[ 2  3  4  4 14 14 16 17 17 18]]
#
#
# [[ 2  6 14  0 12 13  9 16 16 17]]
# actual sorted output is
# [[ 0  2  6  9 12 13 14 16 16 17]]
# sorting done by RNN is
# [[ 0  2  6  9 12 13 14 16 16 17]]
#
#
# [[ 9  9  1 10 12 14 14  2 19 12]]
# actual sorted output is
# [[ 1  2  9  9 10 12 12 14 14 19]]
# sorting done by RNN is
# [[ 1  2  9  9 10 12 12 14 14 19]]
#
#
# [[12 16  3  1  6 18  1 15  4 17]]
# actual sorted output is
# [[ 1  1  3  4  6 12 15 16 17 18]]
# sorting done by RNN is
# [[ 1  1  3  4  6 12 15 16 17 18]]
#
#
# [[ 0 19 14 13  4  1  6 12  2 18]]
# actual sorted output is
# [[ 0  1  2  4  6 12 13 14 18 19]]
# sorting done by RNN is
# [[ 0  1  2  4  6 12 13 14 18 19]]
#
#
# [[ 9  3 12  1  4  3 10  8  1 11]]
# actual sorted output is
# [[ 1  1  3  3  4  8  9 10 11 12]]
# sorting done by RNN is
# [[ 1  1  3  3  4  8  9 10 11 12]]
#
#
# [[ 7  1  2  9  0 18 13  6  3 17]]
# actual sorted output is
# [[ 0  1  2  3  6  7  9 13 17 18]]
# sorting done by RNN is
# [[ 0  1  2  3  6  7  9 13 17 18]]
#
#
# [[ 0  7 11 14  3 15  8 11  5 19]]
# actual sorted output is
# [[ 0  3  5  7  8 11 11 14 15 19]]
# sorting done by RNN is
# [[ 0  3  5  7  8 11 11 14 15 19]]
#
#
# [[ 0  5  9  3 12  9  6 17 13  0]]
# actual sorted output is
# [[ 0  0  3  5  6  9  9 12 13 17]]
# sorting done by RNN is
# [[ 0  0  3  5  6  9  9 12 13 17]]
#
#
# [[11 16 17 13  9  0 17  9  4  1]]
# actual sorted output is
# [[ 0  1  4  9  9 11 13 16 17 17]]
# sorting done by RNN is
# [[ 0  1  4  9  9 11 13 16 17 17]]
#
#
# [[16 10 18 13  8  8 10  9 14  8]]
# actual sorted output is
# [[ 8  8  8  9 10 10 13 14 16 18]]
# sorting done by RNN is
# [[ 8  8  8  9 10 10 13 14 16 18]]
#
#
# [[ 1 12  9  5  5 10 10  8 17  6]]
# actual sorted output is
# [[ 1  5  5  6  8  9 10 10 12 17]]
# sorting done by RNN is
# [[ 1  5  5  6  8  9 10 10 12 17]]
#
#
# [[ 4 19 14 17  5  9  7 10  2 10]]
# actual sorted output is
# [[ 2  4  5  7  9 10 10 14 17 19]]
# sorting done by RNN is
# [[ 2  4  5  7  9 10 10 14 17 19]]
#
#
# [[16  2  5  2 12 13 15  3  3  3]]
# actual sorted output is
# [[ 2  2  3  3  3  5 12 13 15 16]]
# sorting done by RNN is
# [[ 2  2  3  3  5  5 12 13 15 16]]
#
#
# [[14 13  3  9  9  8 13  1 10  0]]
# actual sorted output is
# [[ 0  1  3  8  9  9 10 13 13 14]]
# sorting done by RNN is
# [[ 0  1  3  8  9  9 10 13 13 14]]
#
#
# [[11 18  8 16 11  2  8 10  1 16]]
# actual sorted output is
# [[ 1  2  8  8 10 11 11 16 16 18]]
# sorting done by RNN is
# [[ 1  2  8  8 10 11 11 16 16 18]]
#
#
# [[10 11  1  3 15  0  0 18 13  6]]
# actual sorted output is
# [[ 0  0  1  3  6 10 11 13 15 18]]
# sorting done by RNN is
# [[ 0  0  1  3  6 10 11 13 15 18]]
#
#
# [[ 6  7 16  3  8  6 17  3 15  1]]
# actual sorted output is
# [[ 1  3  3  6  6  7  8 15 16 17]]
# sorting done by RNN is
# [[ 1  3  3  6  6  7  8 15 16 17]]
#
#
# [[19  1 18  0 14 19 15 16  5 19]]
# actual sorted output is
# [[ 0  1  5 14 15 16 18 19 19 19]]
# sorting done by RNN is
# [[ 0  1  5 14 15 16 18 19 19 19]]
#
#
# [[11  3 12  1  9 12  8 10 15 13]]
# actual sorted output is
# [[ 1  3  8  9 10 11 12 12 13 15]]
# sorting done by RNN is
# [[ 1  3  8  9 10 11 12 12 13 15]]
#
#
# [[12 10  8 11  3 14 10 13  3  3]]
# actual sorted output is
# [[ 3  3  3  8 10 10 11 12 13 14]]
# sorting done by RNN is
# [[ 3  3  3  8 10 10 11 12 13 14]]
#
#
# [[ 2 16  1  1  5 15  4  8  9 15]]
# actual sorted output is
# [[ 1  1  2  4  5  8  9 15 15 16]]
# sorting done by RNN is
# [[ 1  1  2  4  5  8  9 15 15 16]]
#
#
# [[15 10 14  5 16 12  8 19 12 14]]
# actual sorted output is
# [[ 5  8 10 12 12 14 14 15 16 19]]
# sorting done by RNN is
# [[ 5  8 10 12 12 14 14 15 16 19]]
#
#
# [[ 8 15  9  0 15  0 19  9  5 15]]
# actual sorted output is
# [[ 0  0  5  8  9  9 15 15 15 19]]
# sorting done by RNN is
# [[ 0  0  5  8  9  9 15 15 15 19]]
#
#
# [[10 19 16 17  3 11 19 18 13 16]]
# actual sorted output is
# [[ 3 10 11 13 16 16 17 18 19 19]]
# sorting done by RNN is
# [[ 3 10 11 13 16 16 17 18 19 19]]
#
#
# [[ 0  8 12  8  9  6 15 17 10 10]]
# actual sorted output is
# [[ 0  6  8  8  9 10 10 12 15 17]]
# sorting done by RNN is
# [[ 0  6  8  8  9 10 10 12 15 17]]
#
#
# [[ 9 14 15  1  1  3 12  7 10 14]]
# actual sorted output is
# [[ 1  1  3  7  9 10 12 14 14 15]]
# sorting done by RNN is
# [[ 1  1  3  7  9 10 12 14 14 15]]
#
#
# [[16 11  3  5 15 18  2 16 17  7]]
# actual sorted output is
# [[ 2  3  5  7 11 15 16 16 17 18]]
# sorting done by RNN is
# [[ 2  3  5  7 11 15 16 16 17 18]]
#
#
# [[ 5  4 15 16 13 17 12 13 18 16]]
# actual sorted output is
# [[ 4  5 12 13 13 15 16 16 17 18]]
# sorting done by RNN is
# [[ 4  5 12 13 13 15 16 16 17 18]]
#
#
# [[ 8  6  1 16  2 17 12 11  7 12]]
# actual sorted output is
# [[ 1  2  6  7  8 11 12 12 16 17]]
# sorting done by RNN is
# [[ 1  2  6  7  8 11 12 12 16 17]]
#
#
# [[ 6  1 15  1  1  7  8  2  2  1]]
# actual sorted output is
# [[ 1  1  1  1  2  2  6  7  8 15]]
# sorting done by RNN is
# [[ 1  1  1  2  2  6  7  8 15 19]]
#
#
# [[ 0  8  3  6  8  3 19  8  1 15]]
# actual sorted output is
# [[ 0  1  3  3  6  8  8  8 15 19]]
# sorting done by RNN is
# [[ 0  1  3  3  6  8  8  8 15 19]]
#
#
# [[13  2 13 10  8  6 14 12  2  1]]
# actual sorted output is
# [[ 1  2  2  6  8 10 12 13 13 14]]
# sorting done by RNN is
# [[ 1  2  2  6  8 10 12 13 13 14]]
#
#
# [[15  8 16 19 19 19  9  6  7 12]]
# actual sorted output is
# [[ 6  7  8  9 12 15 16 19 19 19]]
# sorting done by RNN is
# [[ 6  7  8  9 12 15 16 19 19 19]]
#
#
# [[15  4  5  9  1 10  8 18  5  7]]
# actual sorted output is
# [[ 1  4  5  5  7  8  9 10 15 18]]
# sorting done by RNN is
# [[ 1  4  5  5  7  8  9 10 15 18]]
#
#
# [[11 17 19 19  3 13 17  4 16 15]]
# actual sorted output is
# [[ 3  4 11 13 15 16 17 17 19 19]]
# sorting done by RNN is
# [[ 3  4 11 13 15 16 17 17 19 19]]
#
#
# [[18 13  5 19 11 15 11 16 10 11]]
# actual sorted output is
# [[ 5 10 11 11 11 13 15 16 18 19]]
# sorting done by RNN is
# [[ 5 10 11 11 11 13 15 16 18 19]]
#
#
# [[ 2 16  5 17 18  5  5 17 16  8]]
# actual sorted output is
# [[ 2  5  5  5  8 16 16 17 17 18]]
# sorting done by RNN is
# [[ 2  5  5  5  8 16 16 17 17 18]]
#
#
# [[11 17  2  2 18  5  3 11  6 18]]
# actual sorted output is
# [[ 2  2  3  5  6 11 11 17 18 18]]
# sorting done by RNN is
# [[ 2  2  3  5  6 11 11 17 18 18]]
#
#
# [[ 4 16  9  6  3  7 10 11 14  0]]
# actual sorted output is
# [[ 0  3  4  6  7  9 10 11 14 16]]
# sorting done by RNN is
# [[ 0  3  4  6  7  9 10 11 14 16]]
#
#
# [[ 8  1  3 13 18 16 18  9 17 14]]
# actual sorted output is
# [[ 1  3  8  9 13 14 16 17 18 18]]
# sorting done by RNN is
# [[ 1  3  8  9 13 14 16 17 18 18]]
#
#
# [[ 3  0  2  9  2 18 12 17 13  4]]
# actual sorted output is
# [[ 0  2  2  3  4  9 12 13 17 18]]
# sorting done by RNN is
# [[ 0  2  2  3  4  9 12 13 17 18]]
#
#
# [[18  1 10 15 16  0  5 16 14 10]]
# actual sorted output is
# [[ 0  1  5 10 10 14 15 16 16 18]]
# sorting done by RNN is
# [[ 0  1  5 10 10 14 15 16 16 18]]
#
#
# [[13 19 18 12 19 16 17 16  1  5]]
# actual sorted output is
# [[ 1  5 12 13 16 16 17 18 19 19]]
# sorting done by RNN is
# [[ 1  5 12 13 16 16 17 18 19 19]]
#
#
# [[14 15  7 14 15  2 19  0 18  2]]
# actual sorted output is
# [[ 0  2  2  7 14 14 15 15 18 19]]
# sorting done by RNN is
# [[ 0  2  2  7 14 14 15 15 18 19]]
#
#
# [[16 14 15  7  3  1  0  3  0 11]]
# actual sorted output is
# [[ 0  0  1  3  3  7 11 14 15 16]]
# sorting done by RNN is
# [[ 0  0  1  3  3  7 11 14 15 16]]
#
#
# [[ 8 15 17  3 15  3  4 12  5  2]]
# actual sorted output is
# [[ 2  3  3  4  5  8 12 15 15 17]]
# sorting done by RNN is
# [[ 2  3  3  4  5  8 12 15 15 17]]
#
#
# [[ 9  9 19 13  3 13 15 15 11  6]]
# actual sorted output is
# [[ 3  6  9  9 11 13 13 15 15 19]]
# sorting done by RNN is
# [[ 3  6  9  9 11 13 13 15 15 19]]
#
#
# [[16 12  5 13  4 10 10  1 12  4]]
# actual sorted output is
# [[ 1  4  4  5 10 10 12 12 13 16]]
# sorting done by RNN is
# [[ 1  4  4  5 10 10 12 12 13 16]]
#
#
# [[15  4 10 17  8 13 12 16 19  4]]
# actual sorted output is
# [[ 4  4  8 10 12 13 15 16 17 19]]
# sorting done by RNN is
# [[ 4  4  8 10 12 13 15 16 17 19]]
#
#
# [[ 4  6 14 16 14 15  3 11  4  0]]
# actual sorted output is
# [[ 0  3  4  4  6 11 14 14 15 16]]
# sorting done by RNN is
# [[ 0  3  4  4  6 11 14 14 15 16]]
#
#
# [[ 9  9 12 10 19  6 16  4 14  9]]
# actual sorted output is
# [[ 4  6  9  9  9 10 12 14 16 19]]
# sorting done by RNN is
# [[ 4  6  9  9  9 10 12 14 16 19]]
#
#
# [[17 13  6  5  7  7  1  4 19  8]]
# actual sorted output is
# [[ 1  4  5  6  7  7  8 13 17 19]]
# sorting done by RNN is
# [[ 1  4  5  6  7  7  8 13 17 19]]
#
#
# [[ 9  1 16 19  5 14 13  4  5 11]]
# actual sorted output is
# [[ 1  4  5  5  9 11 13 14 16 19]]
# sorting done by RNN is
# [[ 1  4  5  5  9 11 13 14 16 19]]
#
#
# [[11 19  4  9 19  3 18 19  3  0]]
# actual sorted output is
# [[ 0  3  3  4  9 11 18 19 19 19]]
# sorting done by RNN is
# [[ 0  3  3  4  9 11 18 19 19 19]]
#
#
# [[ 2  5  0 19 19  0 14 13 12 13]]
# actual sorted output is
# [[ 0  0  2  5 12 13 13 14 19 19]]
# sorting done by RNN is
# [[ 0  0  2  5 12 13 13 14 19 19]]
#
#
# [[ 0 11  5 12 11 13  5 16  3  1]]
# actual sorted output is
# [[ 0  1  3  5  5 11 11 12 13 16]]
# sorting done by RNN is
# [[ 0  1  3  5  5 11 11 12 13 16]]
#
#
# [[ 5 17  3  8  9 15  8  0 11  7]]
# actual sorted output is
# [[ 0  3  5  7  8  8  9 11 15 17]]
# sorting done by RNN is
# [[ 0  3  5  7  8  8  9 11 15 17]]
#
#
# [[ 1  0  7  8  5 11  9  5 13  8]]
# actual sorted output is
# [[ 0  1  5  5  7  8  8  9 11 13]]
# sorting done by RNN is
# [[ 0  1  5  5  7  8  9 11 13 13]]
#
#
# [[ 4  8  0  2  8 12 12 11  3 13]]
# actual sorted output is
# [[ 0  2  3  4  8  8 11 12 12 13]]
# sorting done by RNN is
# [[ 0  2  3  4  8  8 11 12 12 13]]
#
#
# [[17 17  5  6 12 14 10  0  5 13]]
# actual sorted output is
# [[ 0  5  5  6 10 12 13 14 17 17]]
# sorting done by RNN is
# [[ 0  5  5  6 10 12 13 14 17 17]]
#
#
# [[ 7 19  6  3 14  7  8  3 16 19]]
# actual sorted output is
# [[ 3  3  6  7  7  8 14 16 19 19]]
# sorting done by RNN is
# [[ 3  3  6  7  7  8 14 16 19 19]]
#
#
# [[ 8 18 18 16  7  6  9  9 15 14]]
# actual sorted output is
# [[ 6  7  8  9  9 14 15 16 18 18]]
# sorting done by RNN is
# [[ 6  7  8  9  9 14 15 16 18 18]]
#
#
# [[13 14  8 13 15  1 17  5 16 14]]
# actual sorted output is
# [[ 1  5  8 13 13 14 14 15 16 17]]
# sorting done by RNN is
# [[ 1  5  8 13 13 14 14 15 16 17]]
#
#
# [[16 19  3 17  9  3 11 16 10  5]]
# actual sorted output is
# [[ 3  3  5  9 10 11 16 16 17 19]]
# sorting done by RNN is
# [[ 3  3  5  9 10 11 16 16 17 19]]
#
#
# [[14 14  7  1 11 16 12  4  6  7]]
# actual sorted output is
# [[ 1  4  6  7  7 11 12 14 14 16]]
# sorting done by RNN is
# [[ 1  4  6  7  7 11 12 14 14 16]]
#
#
# [[ 5  2 18 17 13  1 14  9 18  2]]
# actual sorted output is
# [[ 1  2  2  5  9 13 14 17 18 18]]
# sorting done by RNN is
# [[ 1  2  2  5  9 13 14 17 18 18]]
#
#
# [[13 14 15 11  6 16  7 19 15 15]]
# actual sorted output is
# [[ 6  7 11 13 14 15 15 15 16 19]]
# sorting done by RNN is
# [[ 6  7 11 13 14 15 15 15 16 19]]
#
#
# [[18  9 18  3  9 15 15 17 13  2]]
# actual sorted output is
# [[ 2  3  9  9 13 15 15 17 18 18]]
# sorting done by RNN is
# [[ 2  3  9  9 13 15 15 17 18 18]]
#
#
# [[18 18  3  3  8 18  1  4  1 13]]
# actual sorted output is
# [[ 1  1  3  3  4  8 13 18 18 18]]
# sorting done by RNN is
# [[ 1  1  3  3  4  8 13 18 18 18]]
#
#
# [[ 1 16 19  9  0 14 12 10 10  2]]
# actual sorted output is
# [[ 0  1  2  9 10 10 12 14 16 19]]
# sorting done by RNN is
# [[ 0  1  2  9 10 10 12 14 16 19]]
#
#
# [[ 4  9 18 12  6 11  9 11  1 11]]
# actual sorted output is
# [[ 1  4  6  9  9 11 11 11 12 18]]
# sorting done by RNN is
# [[ 1  4  6  9  9 11 11 11 12 18]]
#
#
# [[14 19  1 14 17  2 15 10 16 18]]
# actual sorted output is
# [[ 1  2 10 14 14 15 16 17 18 19]]
# sorting done by RNN is
# [[ 1  2 10 14 14 15 16 17 18 19]]
#
#
# [[16 17 17  4 19 11  7 11 15 16]]
# actual sorted output is
# [[ 4  7 11 11 15 16 16 17 17 19]]
# sorting done by RNN is
# [[ 4  7 11 11 15 16 16 17 17 19]]
#
#
# [[17  2  8 10  6 17  1  4 14  9]]
# actual sorted output is
# [[ 1  2  4  6  8  9 10 14 17 17]]
# sorting done by RNN is
# [[ 1  2  4  6  8  9 10 14 17 17]]
#
#
# [[ 5  4  1 13  2  6 16 18 12  8]]
# actual sorted output is
# [[ 1  2  4  5  6  8 12 13 16 18]]
# sorting done by RNN is
# [[ 1  2  4  5  6  8 12 13 16 18]]
#
#
# [[ 1 18 13  7 10  2 13 11  2 19]]
# actual sorted output is
# [[ 1  2  2  7 10 11 13 13 18 19]]
# sorting done by RNN is
# [[ 1  2  2  7 10 11 13 13 18 19]]
#
#
# [[19 17 12  3 19  0 10  0  6  9]]
# actual sorted output is
# [[ 0  0  3  6  9 10 12 17 19 19]]
# sorting done by RNN is
# [[ 0  0  3  6  9 10 12 17 19 19]]
#
#
# [[ 3  6  2  5  9  5 10  3 10 19]]
# actual sorted output is
# [[ 2  3  3  5  5  6  9 10 10 19]]
# sorting done by RNN is
# [[ 2  3  3  5  5  6 10 10 10 19]]
#
#
# [[19 19  2 12  3 19 12 11  8 14]]
# actual sorted output is
# [[ 2  3  8 11 12 12 14 19 19 19]]
# sorting done by RNN is
# [[ 2  3  8 11 12 12 14 19 19 19]]
#
#
# [[13 11  0  9 11 15 13 17  1 16]]
# actual sorted output is
# [[ 0  1  9 11 11 13 13 15 16 17]]
# sorting done by RNN is
# [[ 0  1  9 11 11 13 13 15 16 17]]
#
#
# [[ 3 19  6  4 12  3 17  7 15 13]]
# actual sorted output is
# [[ 3  3  4  6  7 12 13 15 17 19]]
# sorting done by RNN is
# [[ 3  3  4  6  7 12 13 15 17 19]]
#
#
# [[19 12  4  6 12  8 15  9  5  8]]
# actual sorted output is
# [[ 4  5  6  8  8  9 12 12 15 19]]
# sorting done by RNN is
# [[ 4  5  6  8  8  9 12 12 15 19]]
#
#
# [[12  2 12  7  5 15  9 17  0  1]]
# actual sorted output is
# [[ 0  1  2  5  7  9 12 12 15 17]]
# sorting done by RNN is
# [[ 0  1  2  5  7  9 12 12 15 17]]
#
#
# [[16 13 10 11 12 14  9 15 10  4]]
# actual sorted output is
# [[ 4  9 10 10 11 12 13 14 15 16]]
# sorting done by RNN is
# [[ 4  9 10 10 11 12 13 14 15 16]]
#
#
# [[ 8  8  7 18 16 13 17  5 10  5]]
# actual sorted output is
# [[ 5  5  7  8  8 10 13 16 17 18]]
# sorting done by RNN is
# [[ 5  5  7  8  8 10 13 16 17 18]]
#
#
# [[19  9 11 18  8  5  9 12 17  9]]
# actual sorted output is
# [[ 5  8  9  9  9 11 12 17 18 19]]
# sorting done by RNN is
# [[ 5  8  9  9  9 11 12 17 18 19]]
#
#
# [[18  6  5  5  8  4  3 16  7 17]]
# actual sorted output is
# [[ 3  4  5  5  6  7  8 16 17 18]]
# sorting done by RNN is
# [[ 3  4  5  5  6  7  8 16 17 18]]
#
#
# [[ 9 17  7 14 12  4 18  0 11  2]]
# actual sorted output is
# [[ 0  2  4  7  9 11 12 14 17 18]]
# sorting done by RNN is
# [[ 0  2  4  7  9 11 12 14 17 18]]
#
#
# [[ 5  7  6 15 16 15 13  2 16  4]]
# actual sorted output is
# [[ 2  4  5  6  7 13 15 15 16 16]]
# sorting done by RNN is
# [[ 2  4  5  6  7 13 15 15 16 16]]
#
#
# [[13  8  7  0  8 13 13  3  5 15]]
# actual sorted output is
# [[ 0  3  5  7  8  8 13 13 13 15]]
# sorting done by RNN is
# [[ 0  3  5  7  8  8 13 13 13 15]]
#
#
# [[13 10 11 11  1  0  6 17  9 10]]
# actual sorted output is
# [[ 0  1  6  9 10 10 11 11 13 17]]
# sorting done by RNN is
# [[ 0  1  6  9 10 10 11 11 13 17]]
#
#
# [[ 7 14 10 17  2 16 17  8 15 18]]
# actual sorted output is
# [[ 2  7  8 10 14 15 16 17 17 18]]
# sorting done by RNN is
# [[ 2  7  8 10 14 15 16 17 17 18]]
#
#
# [[ 6 18 14 16 16 11  8 18 17 18]]
# actual sorted output is
# [[ 6  8 11 14 16 16 17 18 18 18]]
# sorting done by RNN is
# [[ 6  8 11 14 16 16 17 18 18 18]]
#
#
# [[16 19  6 12 15 19  5 10  5 15]]
# actual sorted output is
# [[ 5  5  6 10 12 15 15 16 19 19]]
# sorting done by RNN is
# [[ 5  5  6 10 12 15 15 16 19 19]]
#
#
# [[ 5  0 18  2  3 11 12  6  0 16]]
# actual sorted output is
# [[ 0  0  2  3  5  6 11 12 16 18]]
# sorting done by RNN is
# [[ 0  0  2  3  5  6 11 12 16 18]]
#
#
# [[ 1  2  3  3 16  8 16 15  5  8]]
# actual sorted output is
# [[ 1  2  3  3  5  8  8 15 16 16]]
# sorting done by RNN is
# [[ 1  2  3  3  5  8  8 15 16 16]]
#
#
# [[17 18  7 10 11  9 16  1  1 16]]
# actual sorted output is
# [[ 1  1  7  9 10 11 16 16 17 18]]
# sorting done by RNN is
# [[ 1  1  7  9 10 11 16 16 17 18]]
#
#
# [[ 3 14  4  7  4  7 13  9  5  4]]
# actual sorted output is
# [[ 3  4  4  4  5  7  7  9 13 14]]
# sorting done by RNN is
# [[ 3  4  4  4  5  7  7  9 13 14]]
#
#
# [[19 11 15 13  1  5 11 11 13 11]]
# actual sorted output is
# [[ 1  5 11 11 11 11 13 13 15 19]]
# sorting done by RNN is
# [[ 1  5 11 11 11 11 13 13 15 19]]
#
#
# [[11 16  2 15  6 17  5 14  9  5]]
# actual sorted output is
# [[ 2  5  5  6  9 11 14 15 16 17]]
# sorting done by RNN is
# [[ 2  5  5  6  9 11 14 15 16 17]]
#
#
# [[ 1 10 13  1 12 17 11  5  7 16]]
# actual sorted output is
# [[ 1  1  5  7 10 11 12 13 16 17]]
# sorting done by RNN is
# [[ 1  1  5  7 10 11 12 13 16 17]]
#
#
# [[19 19 17 17 10  6  5 14  9 15]]
# actual sorted output is
# [[ 5  6  9 10 14 15 17 17 19 19]]
# sorting done by RNN is
# [[ 5  6  9 10 14 15 17 17 19 19]]
#
#
# [[16  8 15  0  3 14  4 10 11 10]]
# actual sorted output is
# [[ 0  3  4  8 10 10 11 14 15 16]]
# sorting done by RNN is
# [[ 0  3  4  8 10 10 11 14 15 16]]
#
#
# [[17 17  5 16 11 17 18  7  0  3]]
# actual sorted output is
# [[ 0  3  5  7 11 16 17 17 17 18]]
# sorting done by RNN is
# [[ 0  3  5  7 11 16 17 17 17 18]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9ec552e120f1> in <module>
#      41
#      42 for ind,(X,Y) in enumerate(batch_gen(batch_size, seq_len, max_no)):
# ---> 43     loss, acc = model.train_on_batch(X, Y)
#      44     # We'll test RNN after each 250 iteration to check how well it is performing
#      45     if ind % 250 == 0:
#
# ~/Documents/envs/p3.6/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/Documents/envs/p3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/Documents/envs/p3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Documents/envs/p3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
